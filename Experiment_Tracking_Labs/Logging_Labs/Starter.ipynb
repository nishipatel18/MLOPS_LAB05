# %%
import logging

# 1. Basic Logging Configuration
logging.basicConfig(level=logging.DEBUG,
                    format='%(asctime)s - %(name)s - %(levelname)s - %(message)s')

# 2. Logging Messages at different levels
logging.debug("This is a debug message")
logging.info("This is an info message")
logging.warning("This is a warning message")
logging.error("This is an error message")
logging.critical("This is a critical message")

# 3. Using Custom Loggers
logger = logging.getLogger("my_module")
logger.debug("Debug message from my_module")
logger.info("Info message from my_module")

# 4. Logging Exceptions
try:
    result = 10 / 0
except ZeroDivisionError:
    logging.exception("An error occurred while dividing by zero")

# 5. Controlling Log Levels
logging.getLogger().setLevel(logging.WARNING)

# 6. Log Handlers - console + file
console_handler = logging.StreamHandler()
file_handler = logging.FileHandler('app.log')
logger = logging.getLogger("my_module")
logger.addHandler(console_handler)
logger.addHandler(file_handler)

# 7. Exception with custom logger + handlers
try:
    result = 10 / 0
except ZeroDivisionError:
    logger.exception("An error occurred while dividing by zero")
# Out:
# 2026-03-31 21:57:27,967 - root - DEBUG - This is a debug message
# 2026-03-31 21:57:27,967 - root - INFO - This is an info message
# 2026-03-31 21:57:27,968 - root - WARNING - This is a warning message
# 2026-03-31 21:57:27,969 - root - ERROR - This is an error message
# 2026-03-31 21:57:27,969 - root - CRITICAL - This is a critical message
# 2026-03-31 21:57:27,970 - my_module - DEBUG - Debug message from my_module
# 2026-03-31 21:57:27,970 - my_module - INFO - Info message from my_module
# 2026-03-31 21:57:27,971 - root - ERROR - An error occurred while dividing by zero
# Traceback (most recent call last):
#   File "C:\Users\nishi\AppData\Local\Temp\ipykernel_14388\1998904798.py", line 21, in <module>
#     result = 10 / 0
#              ~~~^~~
# ZeroDivisionError: division by zero
# An error occurred while dividing by zero
# Traceback (most recent call last):
#   File "C:\Users\nishi\AppData\Local\Temp\ipykernel_14388\1998904798.py", line 37, in <module>
#     result = 10 / 0
#              ~~~^~~
# ZeroDivisionError: division by zero
# 2026-03-31 21:57:27,973 - my_module - ERROR - An error occurred while dividing by zero
# Traceback (most recent call last):
#   File "C:\Users\nishi\AppData\Local\Temp\ipykernel_14388\1998904798.py", line 37, in <module>
#     result = 10 / 0
#              ~~~^~~
# ZeroDivisionError: division by zero
